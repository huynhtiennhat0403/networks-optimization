# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('../data/raw/wireless_communication_dataset.csv')
df.describe()
# Out:
#        User Speed (m/s)  Signal Strength (dBm)  Battery Level (%)  \
# count       5000.000000            5000.000000        5000.000000
# mean           8.460698             -85.038160          54.993800
# std            8.368550              14.747225          26.042408
# min            0.000000            -120.000000          10.000000
# 25%            1.320000             -95.222500          33.000000
# 50%            2.740000             -85.225000          55.000000
# 75%           12.987500             -74.820000          78.000000
# max           27.770000             -50.000000         100.000000
#
#        Distance from Base Station (m)  Handover Events  \
# count                     5000.000000      5000.000000
# mean                       551.165042         0.878000
# std                        198.084621         1.209384
# min                         10.000000         0.000000
# 25%                        414.000000         0.000000
# 50%                        550.355000         0.000000
# 75%                        687.272500         2.000000
# max                       1119.090000         4.000000
#
#        Power Consumption (mW)  Transmission Power (dBm)  Throughput (Mbps)  \
# count             5000.000000               5000.000000        5000.000000
# mean               563.534160                 20.201844          23.543712
# std                114.024543                  6.708983          23.168469
# min                229.650000                  5.000000           1.000000
# 25%                477.040000                 15.410000           1.000000
# 50%                535.100000                 20.610000          17.825000
# 75%                668.850000                 25.612500          39.260000
# max                843.580000                 30.000000         110.450000
#
#        Latency (ms)
# count   5000.000000
# mean      77.385900
# std       33.297976
# min        5.000000
# 25%       49.780000
# 50%       76.415000
# 75%      100.685000
# max      168.070000

# %%
df.dtypes
# Out:
# User Speed (m/s)                  float64
# Signal Strength (dBm)             float64
# Battery Level (%)                   int64
# Network Congestion                 object
# Distance from Base Station (m)    float64
# Handover Events                     int64
# Power Consumption (mW)            float64
# Transmission Power (dBm)          float64
# Throughput (Mbps)                 float64
# Latency (ms)                      float64
# RF Link Quality                    object
# dtype: object

# %%
# Convert categorical columns to numerical using hash maps
rf_link_quality_hash_map = {'Poor': 0, 'Moderate': 1, 'Good': 2}
df['RF Link Quality'] = df['RF Link Quality'].map(rf_link_quality_hash_map)

congestion_hash_map = {'Low': 0, 'Medium': 1, 'High': 2}
df['Network Congestion'] = df['Network Congestion'].map(congestion_hash_map).astype(int)

# %%
df['RF Link Quality']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 4995    0
# 4996    1
# 4997    2
# 4998    1
# 4999    2
# Name: RF Link Quality, Length: 5000, dtype: int64

# %%
# Correlation matrix
corr = df.corr()

fig = px.imshow(corr, text_auto=True, aspect="auto", color_continuous_scale='RdBu_r', title='Correlation Matrix')
fig.show()
fig.write_html("../reports/correlation_matrix.html")

# %%
fig = px.histogram(df, x = 'RF Link Quality', nbins=4, color='RF Link Quality')
fig.update_layout(bargap=0.2)
fig.show()

# %%
df[df['RF Link Quality']==0]['Latency (ms)'].describe()
# Out:
# count    2473.000000
# mean      100.688265
# std        26.892531
# min        18.800000
# 25%        83.170000
# 50%       101.160000
# 75%       121.690000
# max       168.070000
# Name: Latency (ms), dtype: float64

# %%
train_df = pd.read_csv('../data/processed/train.csv')

# %%
train_df['RF Link Quality'].value_counts()
# Out:
# RF Link Quality
# 0    1978
# 1    1378
# 2     644
# Name: count, dtype: int64
